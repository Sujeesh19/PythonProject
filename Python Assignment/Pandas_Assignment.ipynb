# %%
# First step is to importing the library
import pandas as pd

# %%
# Second Step to read the dataset
df = pd.read_csv("FlipkartMoblies.csv")

# %%
# Printing the dataset
df
# Out:
#         Brand   Model            Color Memory Storage  Rating  SellingPrice  \
# 0        OPPO     A53  Moonlight Black   4 GB   64 GB     4.5         11990
# 1        OPPO     A53       Mint Cream   4 GB   64 GB     4.5         11990
# 2        OPPO     A53  Moonlight Black   6 GB  128 GB     4.3         13990
# 3        OPPO     A53       Mint Cream   6 GB  128 GB     4.3         13990
# 4        OPPO     A53   Electric Black   4 GB   64 GB     4.5         11990
# ...       ...     ...              ...    ...     ...     ...           ...
# 3109  SAMSUNG  M52 5G    Blazing Black   6 GB  128 GB     4.3         25990
# 3110  SAMSUNG  M52 5G         Icy Blue   6 GB  128 GB     4.3         25489
# 3111  SAMSUNG  M52 5G         Icy Blue   8 GB  128 GB     4.3         27239
# 3112  SAMSUNG  M52 5G      Slate Black   8 GB  128 GB     4.2         22989
# 3113  SAMSUNG  M52 5G         Sky Blue   8 GB  128 GB     4.2         20350
#
#       OriginalPrice  DiscountPercent
# ...

# %%
# Checking the shape of the dataset
df.shape
# Out:
# (3114, 9)

# %%
# prints information about the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3114 entries, 0 to 3113
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            3114 non-null   object
#  1   Model            3114 non-null   object
#  2   Color            3114 non-null   object
#  3   Memory           3071 non-null   object
#  4   Storage          3075 non-null   object
#  5   Rating           2970 non-null   float64
#  6   SellingPrice     3114 non-null   int64
#  7   OriginalPrice    3114 non-null   int64
#  8   DiscountPercent  3114 non-null   int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 219.1+ KB

# %%
# Decribe function gives description of the dataset
df.describe()
# Out:
#             Rating   SellingPrice  OriginalPrice  DiscountPercent
# count  2970.000000    3114.000000    3114.000000      3114.000000
# mean      4.243098   26436.625562   28333.473025         6.103404
# std       0.271991   30066.892622   31525.599889        11.122088
# min       2.300000    1000.000000    1000.000000      -160.000000
# 25%       4.100000    9990.000000   10030.250000         0.000000
# 50%       4.300000   15000.000000   16889.500000         0.000000
# 75%       4.400000   28999.000000   31500.000000        10.000000
# max       5.000000  179900.000000  189999.000000        71.000000

# %%
# Checking for how many null values are present
df.isnull().sum()
# Out:
# Brand                0
# Model                0
# Color                0
# Memory              43
# Storage             39
# Rating             144
# SellingPrice         0
# OriginalPrice        0
# DiscountPercent      0
# dtype: int64

# %%
# Filling Rating column null values with the mean value
df['Rating'].fillna(value=df['Rating'].mean(), inplace = True)

# %%
# Again Checking for how many null values are present
df.isnull().sum()
# Out:
# Brand               0
# Model               0
# Color               0
# Memory             43
# Storage            39
# Rating              0
# SellingPrice        0
# OriginalPrice       0
# DiscountPercent     0
# dtype: int64

# %%
# Filling the Memory column null values with the mode value
df['Memory'].fillna(value=df['Memory'].mode()[0], inplace=True)

# %%
# Again Checking for how many null values are present
df.isnull().sum()
# Out:
# Brand               0
# Model               0
# Color               0
# Memory              0
# Storage            39
# Rating              0
# SellingPrice        0
# OriginalPrice       0
# DiscountPercent     0
# dtype: int64

# %%
# Filling the Storage column null values with the mode value
df['Storage'].fillna(value=df['Storage'].mode()[0], inplace=True)

# %%
# Again Checking for how many null values are present
df.isnull().sum()
# Out:
# Brand              0
# Model              0
# Color              0
# Memory             0
# Storage            0
# Rating             0
# SellingPrice       0
# OriginalPrice      0
# DiscountPercent    0
# dtype: int64

# %%
# Checking for duplicates count
df.duplicated().sum()
# Out:
# 118

# %%
# Removing the duplicate rows from the dataset
df.drop_duplicates(inplace = True)

# %%
# Checking for is their any duplicate rows left
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2996 entries, 0 to 3113
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            2996 non-null   object
#  1   Model            2996 non-null   object
#  2   Color            2996 non-null   object
#  3   Memory           2996 non-null   object
#  4   Storage          2996 non-null   object
#  5   Rating           2996 non-null   float64
#  6   SellingPrice     2996 non-null   int64
#  7   OriginalPrice    2996 non-null   int64
#  8   DiscountPercent  2996 non-null   int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 234.1+ KB

# %%
df.describe()
# Out:
#             Rating   SellingPrice  OriginalPrice  DiscountPercent
# count  2996.000000    2996.000000    2996.000000      2996.000000
# mean      4.235815   25886.988985   27768.057076         6.135180
# std       0.265015   29697.926393   31159.057001        11.213756
# min       2.300000    1000.000000    1000.000000      -160.000000
# 25%       4.100000    9947.500000    9999.000000         0.000000
# 50%       4.300000   14999.000000   15999.000000         0.000000
# 75%       4.400000   27499.000000   29999.000000        10.000000
# max       5.000000  179900.000000  189999.000000        71.000000

# %%
df
# Out:
#         Brand   Model            Color Memory Storage  Rating  SellingPrice  \
# 0        OPPO     A53  Moonlight Black   4 GB   64 GB     4.5         11990
# 1        OPPO     A53       Mint Cream   4 GB   64 GB     4.5         11990
# 2        OPPO     A53  Moonlight Black   6 GB  128 GB     4.3         13990
# 3        OPPO     A53       Mint Cream   6 GB  128 GB     4.3         13990
# 4        OPPO     A53   Electric Black   4 GB   64 GB     4.5         11990
# ...       ...     ...              ...    ...     ...     ...           ...
# 2991  SAMSUNG  M52 5G    Blazing Black   6 GB  128 GB     4.3         25990
# 2992  SAMSUNG  M52 5G         Icy Blue   6 GB  128 GB     4.3         25489
# 2993  SAMSUNG  M52 5G         Icy Blue   8 GB  128 GB     4.3         27239
# 2994  SAMSUNG  M52 5G      Slate Black   8 GB  128 GB     4.2         22989
# 2995  SAMSUNG  M52 5G         Sky Blue   8 GB  128 GB     4.2         20350
#
#       OriginalPrice  DiscountPercent
# ...

# %%
# Now Checking the shape of the dataset
df.shape
# Out:
# (2996, 9)

# %%
# Checking for how many brands Phones are there
Brand_Name = df['Brand'].unique()
print(Brand_Name)
print(len(Brand_Name))
# Out:
# ['OPPO' 'HTC' 'IQOO' 'Google Pixel' 'LG' 'ASUS' 'realme' 'GIONEE' 'Nokia'
#  'Apple' 'SAMSUNG' 'Lenovo' 'Motorola' 'POCO' 'vivo' 'Xiaomi' 'Infinix']
# 17

# %%
# Grouping the Phone in terms of Brand
group = df.groupby(['Brand','Memory'])

# %%
for i, j in group:
    print(i)
    print(j[['Model','Storage','SellingPrice']])
    print("\n")
# Out:
# ('ASUS', '1 GB')
#                    Model Storage  SellingPrice
# 389      Zenfone Go 4.5     8 GB          5299
# 394   Zenfone Go 2nd Gen    8 GB          5299
# 395          Zenfone Go     8 GB          5299
# 402          Zenfone Go     8 GB          5699
# 409      Zenfone Go 4.5     8 GB          5299
# 410   Zenfone Go 2nd Gen    8 GB          5299
# 413          Zenfone Go     8 GB          5699
# 414           Zenfone C     8 GB          6299
# 415          Zenfone Go     8 GB          5699
# 418   Zenfone Go 2nd Gen    8 GB          5299
# 419           Zenfone C     8 GB          6299
# 420           Zenfone C     8 GB          6299
# 421          Zenfone Go     8 GB          4649
# 431  Zenfone Go 4.5 LTE     8 GB          4890
# 432  Zenfone Go 4.5 LTE     8 GB          4890
# 438  Zenfone Go 4.5 LTE     8 GB          4890
# 443  Zenfone Go 4.5 LTE     8 GB          4880
#
#
# ('ASUS', '12 GB')
#               Model Storage  SellingPrice
# ...

# %%
# Lowest price phone
df[df['SellingPrice'] == df['SellingPrice'].min()]
# Out:
#      Brand         Model  Color Memory Storage  Rating  SellingPrice  \
# 963  Nokia  Ta -1010/105  Black   4 MB    4 MB     4.2          1000
# 964  Nokia           105  Black   4 MB    4 MB     4.3          1000
#
#      OriginalPrice  DiscountPercent
# 963           1000                0
# 964           1000                0

# %%
# Highest price phone
df[df['SellingPrice'] == df['SellingPrice'].max()]
# Out:
#       Brand               Model        Color Memory Storage    Rating  \
# 1195  Apple  iPhone 13 Pro Max   Sierra Blue   6 GB    1 TB  4.243098
# 1217  Apple  iPhone 13 Pro Max          Gold   6 GB   64 GB  4.243098
# 1281  Apple  iPhone 13 Pro Max          Gold   6 GB    1 TB  4.243098
# 1322  Apple  iPhone 13 Pro Max      Graphite   6 GB    1 TB  4.243098
# 1366  Apple  iPhone 13 Pro Max        Silver   6 GB    1 TB  4.243098
# 2926  Apple   iPhone 13 Pro Max       Silver    4GB    1 TB  4.700000
# 2933  Apple   iPhone 13 Pro Max         Gold    4GB    1 TB  4.700000
# 2939  Apple   iPhone 13 Pro Max     Graphite    4GB    1 TB  4.700000
# 2940  Apple   iPhone 13 Pro Max  Sierra Blue    4GB    1 TB  4.700000
#
#       SellingPrice  OriginalPrice  DiscountPercent
# 1195        179900         179900                0
# 1217        179900         179900                0
# 1281        179900         179900                0
# 1322        179900         179900                0
# ...

# %%
# Highest Rated Phones
df[df['Rating'] == df.Rating.max()]
# Out:
#         Brand           Model           Color  Memory Storage  Rating  \
# 1214    Apple  iPhone 7 Plus              Red    3 GB  256 GB     5.0
# 1909  SAMSUNG  SM-B310EZDDINS           Black  100 MB  100 MB     5.0
# 2672     vivo         X60 Pro    Shimmer Blue   12 GB  256 GB     5.0
# 2674     vivo           X50        Frost Blue    8 GB  256 GB     5.0
# 2680     vivo             Z1x  Phantom Purple    6 GB   64 GB     5.0
# 2682     vivo              S2   Diamond Black    4 GB  128 GB     5.0
#
#       SellingPrice  OriginalPrice  DiscountPercent
# 1214         85400          85400                0
# 1909          1949           1949                0
# 2672         48780          48780                0
# 2674         44990          44990                0
# 2680         19990          19990                0
# 2682         19990          19990                0

# %%
df[(df['DiscountPercent'] > 50) & (df['Rating'] > 4)]
# Out:
#              Brand              Model           Color Memory Storage  Rating  \
# 302             LG               G8X            Black   6 GB  128 GB     4.4
# 315             LG              Wing      Aurora Gray   8 GB  128 GB     4.2
# 329             LG                G6            Black   4 GB   64 GB     4.2
# 332             LG              Wing     Illusion Sky   8 GB  128 GB     4.2
# 353             LG          Stylus 2            Brown   2 GB   16 GB     4.1
# 363   Google Pixel          Nexus 5X            Black   2 GB   16 GB     4.5
# 440           ASUS               ROG            Black   8 GB  128 GB     4.3
# 859         GIONEE  Marathon M5 Plus       Polar Gold   3 GB   64 GB     4.1
# 1085         Nokia            7 Plus   Black & Copper   4 GB   64 GB     4.3
# 1881       SAMSUNG    Galaxy A8 Star            Black   6 GB   64 GB     4.3
# 1985       SAMSUNG     Galaxy Note 8       Maple Gold   6 GB   64 GB     4.6
# ...
