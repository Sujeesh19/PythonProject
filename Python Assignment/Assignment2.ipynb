# %%
l = [3, 4, 5, 6, 7, [27, 456, 67, 8, 78, 78,], [345, 56, 87, 8, 98, 9], (234, 6657, 6), {"key1": "sujeesh", 234:['a', 'b']}]

# %% [markdown]
# 1. try to reverse the list
# 2. try to access 234 out of list
# 3. try to acess 456 out of list
# 4. try to extract only list collection present in the list
# 5. try to extract "sujeesh"
# 6. try to list all keys present in list
# 7. try to extract all values available in the list

# %%
# 1
l.reverse()
l
# Out:
# [{'key1': 'sujeesh', 234: ['a', 'b']},
#  (234, 6657, 6),
#  [345, 56, 87, 8, 98, 9],
#  [27, 456, 67, 8, 78, 78],
#  7,
#  6,
#  5,
#  4,
#  3]

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# 2
l[1][0]
# Out:
# 234

# %%
# 3
l[3][1]
# Out:
# 456

# %%
# 4
l[2:4]
# Out:
# [[345, 56, 87, 8, 98, 9], [27, 456, 67, 8, 78, 78]]

# %%
# 5
l[0]["key1"]
# Out:
# 'sujeesh'

# %%
# 6
l[0].keys()
# Out:
# dict_keys(['key1', 234])

# %%
# 7
l[0].values()
# Out:
# dict_values(['sujeesh', ['a', 'b']])
